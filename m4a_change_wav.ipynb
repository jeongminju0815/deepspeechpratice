# %%
import os
import pandas as pd

# %%
pwd
# Out:
# '/home/azureuser'

# %%
directory=os.getcwd()

# %%
for filename in os.listdir(directory):
    if filename.endswith(".m4a"):
        # !rm {filename}

# %%
for filename in os.listdir(directory):
    if filename.endswith(".m4a"):
        print(filename)
        #!file {filename} awk
        # !ffmpeg -i {filename} -ar 16000 -ac 1 {filename}.16kHz.mono.wav
# Out:
# ph6-16-2.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph6-16-2.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T02:15:32.000000Z
#   Duration: 00:00:08.51, start: 0.000000, bitrate: 186 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:15:32.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph6-16-2.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:15:32.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     266kB time=00:00:08.51 bitrate= 256.1kbits/s speed= 167x
# video:0kB audio:266kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.028636%
# ph2-10-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph2-10-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-15T07:50:35.000000Z
#   Duration: 00:00:04.22, start: 0.000000, bitrate: 250 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 134 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:50:35.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph2-10-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:50:35.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     132kB time=00:00:04.22 bitrate= 256.1kbits/s speed= 491x
# video:0kB audio:132kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.057706%
# ph3-17-3.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph3-17-3.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-15T08:45:51.000000Z
#   Duration: 00:00:02.71, start: 0.000000, bitrate: 311 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 129 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T08:45:51.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph3-17-3.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T08:45:51.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=      85kB time=00:00:02.70 bitrate= 256.2kbits/s speed= 441x
# video:0kB audio:85kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.089967%
# ph6-17-2.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph6-17-2.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T02:16:12.000000Z
#   Duration: 00:00:06.44, start: 0.000000, bitrate: 206 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 130 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:16:12.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph6-17-2.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:16:12.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     201kB time=00:00:06.44 bitrate= 256.1kbits/s speed= 507x
# video:0kB audio:201kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.037834%
# ph1-7-3.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph1-7-3.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-15T07:18:39.000000Z
#   Duration: 00:00:02.54, start: 0.000000, bitrate: 320 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 126 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:18:39.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph1-7-3.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:18:39.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=      79kB time=00:00:02.53 bitrate= 256.2kbits/s speed= 465x
# video:0kB audio:79kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.096014%
# ph15-4-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph15-4-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T07:38:15.000000Z
#   Duration: 00:00:03.52, start: 0.000000, bitrate: 271 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:38:15.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph15-4-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:38:15.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     110kB time=00:00:03.52 bitrate= 256.2kbits/s speed= 454x
# video:0kB audio:110kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.069247%
# ph7-9-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph7-9-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T02:25:43.000000Z
#   Duration: 00:00:03.52, start: 0.000000, bitrate: 271 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:25:43.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph7-9-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:25:43.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     110kB time=00:00:03.52 bitrate= 256.2kbits/s speed= 438x
# video:0kB audio:110kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.069247%
# ph8-3-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph8-3-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T02:43:06.000000Z
#   Duration: 00:00:04.78, start: 0.000000, bitrate: 232 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 129 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:43:06.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph8-3-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:43:06.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     149kB time=00:00:04.77 bitrate= 256.1kbits/s speed= 503x
# video:0kB audio:149kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.051008%
# ph13-3-2.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph13-3-2.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T07:03:23.000000Z
#   Duration: 00:00:05.01, start: 0.000000, bitrate: 229 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:03:23.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph13-3-2.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:03:23.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     157kB time=00:00:05.01 bitrate= 256.1kbits/s speed= 470x
# video:0kB audio:157kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048621%
# ph15-4-2.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph15-4-2.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T07:38:26.000000Z
#   Duration: 00:00:04.29, start: 0.000000, bitrate: 244 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 129 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:38:26.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph15-4-2.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:38:26.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     134kB time=00:00:04.28 bitrate= 256.1kbits/s speed= 486x
# video:0kB audio:134kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.056845%
# ph13-12-3.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph13-12-3.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T07:09:02.000000Z
#   Duration: 00:00:05.40, start: 0.000000, bitrate: 221 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 130 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:09:02.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph13-12-3.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:09:02.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     169kB time=00:00:05.39 bitrate= 256.1kbits/s speed= 501x
# video:0kB audio:169kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.045161%
# ph1-13-2.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph1-13-2.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-15T07:22:21.000000Z
#   Duration: 00:00:04.10, start: 0.000000, bitrate: 251 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:22:21.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph1-13-2.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:22:21.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     128kB time=00:00:04.09 bitrate= 256.2kbits/s speed= 464x
# video:0kB audio:128kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.059509%
# ph16-3-3.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph16-3-3.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T07:51:58.000000Z
#   Duration: 00:00:03.22, start: 0.000000, bitrate: 282 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 129 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:51:58.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph16-3-3.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:51:58.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     101kB time=00:00:03.22 bitrate= 256.2kbits/s speed= 482x
# video:0kB audio:101kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.075668%
# ph2-4-2.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph2-4-2.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-15T07:46:54.000000Z
#   Duration: 00:00:03.50, start: 0.000000, bitrate: 272 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:46:54.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph2-4-2.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T07:46:54.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     109kB time=00:00:03.49 bitrate= 256.2kbits/s speed= 464x
# video:0kB audio:109kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.069669%
# ph7-10-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph7-10-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T02:26:14.000000Z
#   Duration: 00:00:04.76, start: 0.000000, bitrate: 234 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 130 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:26:14.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph7-10-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:26:14.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     149kB time=00:00:04.75 bitrate= 256.1kbits/s speed= 288x
# video:0kB audio:149kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.051237%
# ph3-13-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph3-13-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-15T08:42:28.000000Z
#   Duration: 00:00:05.70, start: 0.000000, bitrate: 216 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 130 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T08:42:28.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph3-13-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T08:42:28.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     178kB time=00:00:05.69 bitrate= 256.1kbits/s speed= 515x
# video:0kB audio:178kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042793%
# ph3-8-3.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph3-8-3.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-15T08:40:03.000000Z
#   Duration: 00:00:02.99, start: 0.000000, bitrate: 293 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-15T08:40:03.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph3-8-3.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
# ...
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph4-10-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T01:36:29.000000Z
#   Duration: 00:00:04.20, start: 0.000000, bitrate: 248 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T01:36:29.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph4-10-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T01:36:29.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     131kB time=00:00:04.20 bitrate= 256.1kbits/s speed= 572x
# video:0kB audio:131kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.057999%
# ph6-10-3.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph6-10-3.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T02:11:33.000000Z
#   Duration: 00:00:05.57, start: 0.000000, bitrate: 218 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 129 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:11:33.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph6-10-3.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T02:11:33.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     174kB time=00:00:05.56 bitrate= 256.1kbits/s speed= 594x
# video:0kB audio:174kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.043777%
# ph16-3-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph16-3-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T07:51:38.000000Z
#   Duration: 00:00:03.33, start: 0.000000, bitrate: 276 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:51:38.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph16-3-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:51:38.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     104kB time=00:00:03.32 bitrate= 256.2kbits/s speed= 539x
# video:0kB audio:104kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.073242%
# ph10-3-2.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph10-3-2.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T06:08:35.000000Z
#   Duration: 00:00:03.78, start: 0.000000, bitrate: 262 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 132 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T06:08:35.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph10-3-2.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T06:08:35.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     118kB time=00:00:03.77 bitrate= 256.2kbits/s speed= 533x
# video:0kB audio:118kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.064552%
# ph14-4-1.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph14-4-1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T07:24:57.000000Z
#   Duration: 00:00:04.61, start: 0.000000, bitrate: 238 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:24:57.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph14-4-1.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T07:24:57.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     144kB time=00:00:04.60 bitrate= 256.1kbits/s speed= 542x
# video:0kB audio:144kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.052897%
# ph8-12-3.m4a
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'ph8-12-3.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2021-10-18T05:41:24.000000Z
#   Duration: 00:00:04.76, start: 0.000000, bitrate: 234 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 131 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T05:41:24.000000Z
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'ph8-12-3.m4a.16kHz.mono.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2021-10-18T05:41:24.000000Z
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     149kB time=00:00:04.75 bitrate= 256.1kbits/s speed= 544x
# video:0kB audio:149kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.051237%

# %%
for filename in os.listdir(directory):
    if filename.endswith(".wav"):
        print(filename)
# Out:
# ph4-11-1.m4a.16kHz.mono.wav
# ph10-3-3.m4a.16kHz.mono.wav
# ph6-14-2.m4a.16kHz.mono.wav
# ph6-16-3.m4a.16kHz.mono.wav
# ph2-2-2.m4a.16kHz.mono.wav
# ph7-15-3.m4a.16kHz.mono.wav
# ph17-14-1.m4a.16kHz.mono.wav
# ph10-5-3.m4a.16kHz.mono.wav
# ph13-15-3.m4a.16kHz.mono.wav
# ph2-3-3.m4a.16kHz.mono.wav
# ph15-9-3.m4a.16kHz.mono.wav
# ph11-11-2.m4a.16kHz.mono.wav
# ph7-10-1.m4a.16kHz.mono.wav
# ph6-17-3.m4a.16kHz.mono.wav
# ph11-4-3.m4a.16kHz.mono.wav
# ph12-1-1.m4a.16kHz.mono.wav
# ph5-3-3.m4a.16kHz.mono.wav
# ph16-2-3.m4a.16kHz.mono.wav
# ph15-2-1.m4a.16kHz.mono.wav
# ph8-12-1.m4a.16kHz.mono.wav
# ph3-9-2.m4a.16kHz.mono.wav
# ph7-2-3.m4a.16kHz.mono.wav
# ph3-14-2.m4a.16kHz.mono.wav
# ph4-1-2.m4a.16kHz.mono.wav
# ph11-3-3.m4a.16kHz.mono.wav
# ph10-17-1.m4a.16kHz.mono.wav
# ph4-6-1.m4a.16kHz.mono.wav
# ph12-9-2.m4a.16kHz.mono.wav
# ph7-12-3.m4a.16kHz.mono.wav
# ph6-14-3.m4a.16kHz.mono.wav
# ph6-13-2.m4a.16kHz.mono.wav
# ph14-7-1.m4a.16kHz.mono.wav
# ph1-14-2.m4a.16kHz.mono.wav
# ph2-9-3.m4a.16kHz.mono.wav
# ph2-13-3.m4a.16kHz.mono.wav
# ph14-5-2.m4a.16kHz.mono.wav
# ph8-14-2.m4a.16kHz.mono.wav
# ph4-12-1.m4a.16kHz.mono.wav
# ph11-12-1.m4a.16kHz.mono.wav
# ph4-14-2.m4a.16kHz.mono.wav
# ph16-14-2.m4a.16kHz.mono.wav
# ph4-3-3.m4a.16kHz.mono.wav
# ph9-3-1.m4a.16kHz.mono.wav
# ph1-5-2.m4a.16kHz.mono.wav
# ph8-15-3.m4a.16kHz.mono.wav
# ph14-4-3.m4a.16kHz.mono.wav
# ph5-6-1.m4a.16kHz.mono.wav
# ph11-14-3.m4a.16kHz.mono.wav
# ph9-10-2.m4a.16kHz.mono.wav
# ph6-8-2.m4a.16kHz.mono.wav
# ph13-17-2.m4a.16kHz.mono.wav
# ph9-6-3.m4a.16kHz.mono.wav
# ph6-10-1.m4a.16kHz.mono.wav
# ph1-12-3.m4a.16kHz.mono.wav
# ph5-11-1.m4a.16kHz.mono.wav
# ph16-3-2.m4a.16kHz.mono.wav
# ph17-14-2.m4a.16kHz.mono.wav
# ph17-7-1.m4a.16kHz.mono.wav
# ph10-1-1.m4a.16kHz.mono.wav
# ph16-1-2.m4a.16kHz.mono.wav
# ph12-1-3.m4a.16kHz.mono.wav
# ph11-6-1.m4a.16kHz.mono.wav
# ph3-8-2.m4a.16kHz.mono.wav
# ph2-15-3.m4a.16kHz.mono.wav
# ph2-6-2.m4a.16kHz.mono.wav
# ph2-1-3.m4a.16kHz.mono.wav
# ph1-15-2.m4a.16kHz.mono.wav
# ph16-11-2.m4a.16kHz.mono.wav
# ph6-2-3.m4a.16kHz.mono.wav
# ph16-12-1.m4a.16kHz.mono.wav
# ph10-15-3.m4a.16kHz.mono.wav
# ph3-6-1.m4a.16kHz.mono.wav
# ph2-1-2.m4a.16kHz.mono.wav
# ph11-10-3.m4a.16kHz.mono.wav
# ph2-14-3.m4a.16kHz.mono.wav
# ph6-11-3.m4a.16kHz.mono.wav
# ph14-10-2.m4a.16kHz.mono.wav
# ph10-14-2.m4a.16kHz.mono.wav
# ph4-16-2.m4a.16kHz.mono.wav
# ph13-8-2.m4a.16kHz.mono.wav
# ph12-15-3.m4a.16kHz.mono.wav
# ph14-6-2.m4a.16kHz.mono.wav
# ph10-17-3.m4a.16kHz.mono.wav
# ph13-10-1.m4a.16kHz.mono.wav
# ph7-13-3.m4a.16kHz.mono.wav
# ph7-2-1.m4a.16kHz.mono.wav
# ph2-10-1.m4a.16kHz.mono.wav
# ph2-10-2.m4a.16kHz.mono.wav
# ph7-5-1.m4a.16kHz.mono.wav
# ph3-13-2.m4a.16kHz.mono.wav
# ph17-3-3.m4a.16kHz.mono.wav
# ph15-11-1.m4a.16kHz.mono.wav
# ph7-11-3.m4a.16kHz.mono.wav
# ph13-6-2.m4a.16kHz.mono.wav
# ph10-3-2.m4a.16kHz.mono.wav
# ph5-15-2.m4a.16kHz.mono.wav
# ph2-11-1.m4a.16kHz.mono.wav
# ph12-14-2.m4a.16kHz.mono.wav
# ph9-1-1.m4a.16kHz.mono.wav
# ph15-10-2.m4a.16kHz.mono.wav
# ph13-4-2.m4a.16kHz.mono.wav
# ph4-15-1.m4a.16kHz.mono.wav
# ph16-15-2.m4a.16kHz.mono.wav
# ph13-1-2.m4a.16kHz.mono.wav
# ph17-13-1.m4a.16kHz.mono.wav
# ph11-10-2.m4a.16kHz.mono.wav
# ph12-16-1.m4a.16kHz.mono.wav
# ph17-7-3.m4a.16kHz.mono.wav
# ph14-1-1.m4a.16kHz.mono.wav
# ph9-7-3.m4a.16kHz.mono.wav
# ph5-17-2.m4a.16kHz.mono.wav
# ph5-9-3.m4a.16kHz.mono.wav
# ph6-6-3.m4a.16kHz.mono.wav
# ph15-6-1.m4a.16kHz.mono.wav
# ph16-13-2.m4a.16kHz.mono.wav
# ph2-1-1.m4a.16kHz.mono.wav
# ph3-3-3.m4a.16kHz.mono.wav
# ph7-3-3.m4a.16kHz.mono.wav
# ph9-14-3.m4a.16kHz.mono.wav
# ph7-7-2.m4a.16kHz.mono.wav
# ph13-12-2.m4a.16kHz.mono.wav
# ph6-1-1.m4a.16kHz.mono.wav
# ph7-10-3.m4a.16kHz.mono.wav
# ph1-7-3.m4a.16kHz.mono.wav
# ph13-17-3.m4a.16kHz.mono.wav
# ph11-10-1.m4a.16kHz.mono.wav
# ph6-6-1.m4a.16kHz.mono.wav
# ph3-8-3.m4a.16kHz.mono.wav
# ph1-11-1.m4a.16kHz.mono.wav
# ph4-7-2.m4a.16kHz.mono.wav
# ph9-15-3.m4a.16kHz.mono.wav
# ph3-6-3.m4a.16kHz.mono.wav
# ph15-9-1.m4a.16kHz.mono.wav
# ph15-6-3.m4a.16kHz.mono.wav
# ph4-17-1.m4a.16kHz.mono.wav
# ph15-14-3.m4a.16kHz.mono.wav
# ph3-6-2.m4a.16kHz.mono.wav
# ph1-3-1.m4a.16kHz.mono.wav
# ph14-14-2.m4a.16kHz.mono.wav
# ph5-10-2.m4a.16kHz.mono.wav
# ph4-16-3.m4a.16kHz.mono.wav
# ph10-9-3.m4a.16kHz.mono.wav
# ph17-13-3.m4a.16kHz.mono.wav
# ph16-1-3.m4a.16kHz.mono.wav
# ph12-13-2.m4a.16kHz.mono.wav
# ph1-13-1.m4a.16kHz.mono.wav
# ph12-10-3.m4a.16kHz.mono.wav
# ph4-11-3.m4a.16kHz.mono.wav
# ph4-1-1.m4a.16kHz.mono.wav
# ph5-12-3.m4a.16kHz.mono.wav
# ph1-12-2.m4a.16kHz.mono.wav
# ph14-4-1.m4a.16kHz.mono.wav
# ph2-6-3.m4a.16kHz.mono.wav
# ph8-14-3.m4a.16kHz.mono.wav
# ph12-13-3.m4a.16kHz.mono.wav
# ph2-7-1.m4a.16kHz.mono.wav
# ph4-7-1.m4a.16kHz.mono.wav
# ph8-7-2.m4a.16kHz.mono.wav
# ph13-8-1.m4a.16kHz.mono.wav
# ph2-8-1.m4a.16kHz.mono.wav
# ph12-1-2.m4a.16kHz.mono.wav
# ph11-14-2.m4a.16kHz.mono.wav
# ph9-3-3.m4a.16kHz.mono.wav
# ph10-3-1.m4a.16kHz.mono.wav
# ph15-1-2.m4a.16kHz.mono.wav
# ph9-6-1.m4a.16kHz.mono.wav
# ph11-3-2.m4a.16kHz.mono.wav
# ph17-10-1.m4a.16kHz.mono.wav
# ph15-15-1.m4a.16kHz.mono.wav
# ph4-12-2.m4a.16kHz.mono.wav
# ph16-5-2.m4a.16kHz.mono.wav
# ph4-14-1.m4a.16kHz.mono.wav
# ph17-12-2.m4a.16kHz.mono.wav
# ph16-7-3.m4a.16kHz.mono.wav
# ph12-3-2.m4a.16kHz.mono.wav
# ph10-17-2.m4a.16kHz.mono.wav
# ph15-12-1.m4a.16kHz.mono.wav
# ph12-9-1.m4a.16kHz.mono.wav
# ph7-9-1.m4a.16kHz.mono.wav
# ph2-3-2.m4a.16kHz.mono.wav
# ph9-14-2.m4a.16kHz.mono.wav
# ph11-15-1.m4a.16kHz.mono.wav
# ph17-9-2.m4a.16kHz.mono.wav
# ph10-2-3.m4a.16kHz.mono.wav
# ph3-17-1.m4a.16kHz.mono.wav
# ph7-7-1.m4a.16kHz.mono.wav
# ph5-12-2.m4a.16kHz.mono.wav
# ph10-6-3.m4a.16kHz.mono.wav
# ph9-4-2.m4a.16kHz.mono.wav
# ph11-1-2.m4a.16kHz.mono.wav
# ph17-8-3.m4a.16kHz.mono.wav
# ph5-7-3.m4a.16kHz.mono.wav
# ph10-15-2.m4a.16kHz.mono.wav
# ph3-1-2.m4a.16kHz.mono.wav
# ph13-7-1.m4a.16kHz.mono.wav
# ph16-13-1.m4a.16kHz.mono.wav
# ph11-7-2.m4a.16kHz.mono.wav
# ph11-5-3.m4a.16kHz.mono.wav
# ph16-11-1.m4a.16kHz.mono.wav
# ph9-17-2.m4a.16kHz.mono.wav
# ph2-4-1.m4a.16kHz.mono.wav
# ph6-13-3.m4a.16kHz.mono.wav
# ph4-4-2.m4a.16kHz.mono.wav
# ph12-3-1.m4a.16kHz.mono.wav
# ph6-6-2.m4a.16kHz.mono.wav
# ph5-17-3.m4a.16kHz.mono.wav
# ph5-2-2.m4a.16kHz.mono.wav
# ph8-11-3.m4a.16kHz.mono.wav
# ph5-7-2.m4a.16kHz.mono.wav
# ph13-4-3.m4a.16kHz.mono.wav
# ph7-14-1.m4a.16kHz.mono.wav
# ph15-13-2.m4a.16kHz.mono.wav
# ph1-5-3.m4a.16kHz.mono.wav
# ph12-3-3.m4a.16kHz.mono.wav
# ph2-12-2.m4a.16kHz.mono.wav
# ph15-4-2.m4a.16kHz.mono.wav
# ph10-16-2.m4a.16kHz.mono.wav
# ph3-9-3.m4a.16kHz.mono.wav
# ph7-4-1.m4a.16kHz.mono.wav
# ph13-14-1.m4a.16kHz.mono.wav
# ph7-9-3.m4a.16kHz.mono.wav
# ph10-2-2.m4a.16kHz.mono.wav
# ph6-8-1.m4a.16kHz.mono.wav
# ph14-13-2.m4a.16kHz.mono.wav
# ph6-1-2.m4a.16kHz.mono.wav
# ph13-1-1.m4a.16kHz.mono.wav
# ph4-11-2.m4a.16kHz.mono.wav
# ph1-7-1.m4a.16kHz.mono.wav
# ph5-14-2.m4a.16kHz.mono.wav
# ph9-8-2.m4a.16kHz.mono.wav
# ph12-6-1.m4a.16kHz.mono.wav
# ph4-6-2.m4a.16kHz.mono.wav
# ph3-5-2.m4a.16kHz.mono.wav
# ph5-17-1.m4a.16kHz.mono.wav
# ph9-1-3.m4a.16kHz.mono.wav
# ph5-9-2.m4a.16kHz.mono.wav
# ph14-16-3.m4a.16kHz.mono.wav
# ph17-2-1.m4a.16kHz.mono.wav
# ph4-8-3.m4a.16kHz.mono.wav
# ph10-9-2.m4a.16kHz.mono.wav
# ph17-11-3.m4a.16kHz.mono.wav
# ph1-17-1.m4a.16kHz.mono.wav
# ph13-10-2.m4a.16kHz.mono.wav
# ph15-8-1.m4a.16kHz.mono.wav
# ph15-14-1.m4a.16kHz.mono.wav
# ph14-16-2.m4a.16kHz.mono.wav
# ph9-16-1.m4a.16kHz.mono.wav
# ph13-3-1.m4a.16kHz.mono.wav
# ph11-6-3.m4a.16kHz.mono.wav
# ph8-10-2.m4a.16kHz.mono.wav
# ph16-16-3.m4a.16kHz.mono.wav
# ph13-6-1.m4a.16kHz.mono.wav
# ph11-8-2.m4a.16kHz.mono.wav
# ph16-10-1.m4a.16kHz.mono.wav
# ph16-8-3.m4a.16kHz.mono.wav
# ph9-2-1.m4a.16kHz.mono.wav
# ph12-16-3.m4a.16kHz.mono.wav
# ph12-14-3.m4a.16kHz.mono.wav
# ph16-9-3.m4a.16kHz.mono.wav
# ph11-1-1.m4a.16kHz.mono.wav
# ph13-2-3.m4a.16kHz.mono.wav
# ph15-8-2.m4a.16kHz.mono.wav
# ph14-8-1.m4a.16kHz.mono.wav
# ph13-2-1.m4a.16kHz.mono.wav
# ph14-7-3.m4a.16kHz.mono.wav
# ph15-5-2.m4a.16kHz.mono.wav
# ph4-9-2.m4a.16kHz.mono.wav
# ph13-13-2.m4a.16kHz.mono.wav
# ph1-1-1.m4a.16kHz.mono.wav
# ph13-3-3.m4a.16kHz.mono.wav
# ph13-2-2.m4a.16kHz.mono.wav
# ph11-4-1.m4a.16kHz.mono.wav
# ph5-1-2.m4a.16kHz.mono.wav
# ph16-4-1.m4a.16kHz.mono.wav
# ph11-15-3.m4a.16kHz.mono.wav
# ph10-4-1.m4a.16kHz.mono.wav
# ph2-5-2.m4a.16kHz.mono.wav
# ph16-4-3.m4a.16kHz.mono.wav
# ph16-2-1.m4a.16kHz.mono.wav
# ph1-4-2.m4a.16kHz.mono.wav
# ph10-13-1.m4a.16kHz.mono.wav
# ph3-2-1.m4a.16kHz.mono.wav
# ph2-12-1.m4a.16kHz.mono.wav
# ph15-5-3.m4a.16kHz.mono.wav
# ph1-1-2.m4a.16kHz.mono.wav
# ph4-13-1.m4a.16kHz.mono.wav
# ph10-14-3.m4a.16kHz.mono.wav
# ph13-9-3.m4a.16kHz.mono.wav
# ph7-11-2.m4a.16kHz.mono.wav
# ph16-8-2.m4a.16kHz.mono.wav
# ph16-3-1.m4a.16kHz.mono.wav
# ph8-9-3.m4a.16kHz.mono.wav
# ph16-7-1.m4a.16kHz.mono.wav
# ph17-9-3.m4a.16kHz.mono.wav
# ph14-8-2.m4a.16kHz.mono.wav
# ph1-16-1.m4a.16kHz.mono.wav
# ph6-14-1.m4a.16kHz.mono.wav
# ph10-4-2.m4a.16kHz.mono.wav
# ph4-17-3.m4a.16kHz.mono.wav
# ph11-4-2.m4a.16kHz.mono.wav
# ph17-3-2.m4a.16kHz.mono.wav
# ph12-10-2.m4a.16kHz.mono.wav
# ph16-11-3.m4a.16kHz.mono.wav
# ph6-16-1.m4a.16kHz.mono.wav
# ph8-5-2.m4a.16kHz.mono.wav
# ph6-7-1.m4a.16kHz.mono.wav
# ph8-2-3.m4a.16kHz.mono.wav
# ph1-16-3.m4a.16kHz.mono.wav
# ph8-1-3.m4a.16kHz.mono.wav
# ph16-2-2.m4a.16kHz.mono.wav
# ph15-3-2.m4a.16kHz.mono.wav
# ph14-9-3.m4a.16kHz.mono.wav
# ph5-1-1.m4a.16kHz.mono.wav
# ph1-9-2.m4a.16kHz.mono.wav
# ph3-3-2.m4a.16kHz.mono.wav
# ph13-16-2.m4a.16kHz.mono.wav
# ph16-17-3.m4a.16kHz.mono.wav
# ph2-4-3.m4a.16kHz.mono.wav
# ph5-13-1.m4a.16kHz.mono.wav
# ph14-14-3.m4a.16kHz.mono.wav
# ph14-12-1.m4a.16kHz.mono.wav
# ph2-14-1.m4a.16kHz.mono.wav
# ph11-15-2.m4a.16kHz.mono.wav
# ph4-4-1.m4a.16kHz.mono.wav
# ph2-17-3.m4a.16kHz.mono.wav
# ph4-5-1.m4a.16kHz.mono.wav
# ph7-10-2.m4a.16kHz.mono.wav
# ph14-4-2.m4a.16kHz.mono.wav
# ph13-11-1.m4a.16kHz.mono.wav
# ph11-13-2.m4a.16kHz.mono.wav
# ph10-7-1.m4a.16kHz.mono.wav
# ph1-1-3.m4a.16kHz.mono.wav
# ph5-6-3.m4a.16kHz.mono.wav
# ph3-16-3.m4a.16kHz.mono.wav
# ph1-15-3.m4a.16kHz.mono.wav
# ph15-2-3.m4a.16kHz.mono.wav
# ph7-5-3.m4a.16kHz.mono.wav
# ph12-4-3.m4a.16kHz.mono.wav
# ph17-8-1.m4a.16kHz.mono.wav
# ph2-14-2.m4a.16kHz.mono.wav
# ph17-5-3.m4a.16kHz.mono.wav
# ph11-2-1.m4a.16kHz.mono.wav
# ph6-8-3.m4a.16kHz.mono.wav
# ph16-17-2.m4a.16kHz.mono.wav
# ph16-5-3.m4a.16kHz.mono.wav
# ph7-13-2.m4a.16kHz.mono.wav
# ph1-10-2.m4a.16kHz.mono.wav
# ph7-8-2.m4a.16kHz.mono.wav
# ph3-2-2.m4a.16kHz.mono.wav
# ph15-16-2.m4a.16kHz.mono.wav
# ph14-8-3.m4a.16kHz.mono.wav
# ph7-7-3.m4a.16kHz.mono.wav
# ph17-4-3.m4a.16kHz.mono.wav
# ph4-9-1.m4a.16kHz.mono.wav
# ph14-2-2.m4a.16kHz.mono.wav
# ph7-1-1.m4a.16kHz.mono.wav
# ph9-16-3.m4a.16kHz.mono.wav
# ph13-13-1.m4a.16kHz.mono.wav
# ph2-8-2.m4a.16kHz.mono.wav
# ph12-14-1.m4a.16kHz.mono.wav
# ph3-12-3.m4a.16kHz.mono.wav
# ph14-12-2.m4a.16kHz.mono.wav
# ph6-3-3.m4a.16kHz.mono.wav
# ph11-13-1.m4a.16kHz.mono.wav
# ph17-3-1.m4a.16kHz.mono.wav
# ph15-9-2.m4a.16kHz.mono.wav
# ph14-5-3.m4a.16kHz.mono.wav
# ph1-2-3.m4a.16kHz.mono.wav
# ph15-2-2.m4a.16kHz.mono.wav
# ph10-7-2.m4a.16kHz.mono.wav
# ph3-12-1.m4a.16kHz.mono.wav
# ph16-5-1.m4a.16kHz.mono.wav
# ph7-15-1.m4a.16kHz.mono.wav
# ph1-16-2.m4a.16kHz.mono.wav
# ph15-7-1.m4a.16kHz.mono.wav
# ph4-9-3.m4a.16kHz.mono.wav
# ph14-10-3.m4a.16kHz.mono.wav
# ph15-17-3.m4a.16kHz.mono.wav
# ph10-11-2.m4a.16kHz.mono.wav
# ph8-8-1.m4a.16kHz.mono.wav
# ph5-8-1.m4a.16kHz.mono.wav
# ph5-11-3.m4a.16kHz.mono.wav
# ph10-1-2.m4a.16kHz.mono.wav
# ph15-4-3.m4a.16kHz.mono.wav
# ph8-10-1.m4a.16kHz.mono.wav
# ph9-2-2.m4a.16kHz.mono.wav
# ph12-2-3.m4a.16kHz.mono.wav
# ph7-4-3.m4a.16kHz.mono.wav
# ph14-6-3.m4a.16kHz.mono.wav
# ph16-9-2.m4a.16kHz.mono.wav
# ph15-13-1.m4a.16kHz.mono.wav
# ph7-12-1.m4a.16kHz.mono.wav
# ph14-15-3.m4a.16kHz.mono.wav
# ph1-5-1.m4a.16kHz.mono.wav
# ph7-11-1.m4a.16kHz.mono.wav
# ph9-14-1.m4a.16kHz.mono.wav
# ph8-6-3.m4a.16kHz.mono.wav
# ph8-17-2.m4a.16kHz.mono.wav
# ph7-16-3.m4a.16kHz.mono.wav
# ph6-11-2.m4a.16kHz.mono.wav
# ph6-1-3.m4a.16kHz.mono.wav
# ph10-16-3.m4a.16kHz.mono.wav
# ph1-9-3.m4a.16kHz.mono.wav
# ph13-11-3.m4a.16kHz.mono.wav
# ph6-10-3.m4a.16kHz.mono.wav
# ph11-3-1.m4a.16kHz.mono.wav
# ph11-12-2.m4a.16kHz.mono.wav
# ph2-9-2.m4a.16kHz.mono.wav
# ph8-16-2.m4a.16kHz.mono.wav
# ph8-13-3.m4a.16kHz.mono.wav
# ph16-7-2.m4a.16kHz.mono.wav
# ph13-15-1.m4a.16kHz.mono.wav
# ph6-4-2.m4a.16kHz.mono.wav
# ph15-17-1.m4a.16kHz.mono.wav
# ph7-17-3.m4a.16kHz.mono.wav
# ph8-2-1.m4a.16kHz.mono.wav
# ph17-15-2.m4a.16kHz.mono.wav
# ph14-11-1.m4a.16kHz.mono.wav
# ph3-11-3.m4a.16kHz.mono.wav
# ph10-5-2.m4a.16kHz.mono.wav
# ph3-7-3.m4a.16kHz.mono.wav
# ph7-17-2.m4a.16kHz.mono.wav
# ph9-16-2.m4a.16kHz.mono.wav
# ph15-17-2.m4a.16kHz.mono.wav
# ph13-17-1.m4a.16kHz.mono.wav
# ph13-7-2.m4a.16kHz.mono.wav
# ph14-11-2.m4a.16kHz.mono.wav
# ph1-13-2.m4a.16kHz.mono.wav
# ph9-8-3.m4a.16kHz.mono.wav
# ph11-7-1.m4a.16kHz.mono.wav
# ph3-15-3.m4a.16kHz.mono.wav
# ph6-13-1.m4a.16kHz.mono.wav
# ph6-2-2.m4a.16kHz.mono.wav
# ph15-16-3.m4a.16kHz.mono.wav
# ph6-15-2.m4a.16kHz.mono.wav
# ph17-11-2.m4a.16kHz.mono.wav
# ph9-5-3.m4a.16kHz.mono.wav
# ph16-16-2.m4a.16kHz.mono.wav
# ph12-15-2.m4a.16kHz.mono.wav
# ph9-9-2.m4a.16kHz.mono.wav
# ph16-6-1.m4a.16kHz.mono.wav
# ph3-17-2.m4a.16kHz.mono.wav
# ph12-12-3.m4a.16kHz.mono.wav
# ph12-4-1.m4a.16kHz.mono.wav
# ph16-8-1.m4a.16kHz.mono.wav
# ph6-15-1.m4a.16kHz.mono.wav
# ph14-1-2.m4a.16kHz.mono.wav
# ph8-3-2.m4a.16kHz.mono.wav
# ph4-1-3.m4a.16kHz.mono.wav
# ph14-13-3.m4a.16kHz.mono.wav
# ph10-14-1.m4a.16kHz.mono.wav
# ph3-15-2.m4a.16kHz.mono.wav
# ph2-16-1.m4a.16kHz.mono.wav
# ph6-5-3.m4a.16kHz.mono.wav
# ph14-17-3.m4a.16kHz.mono.wav
# ph10-6-1.m4a.16kHz.mono.wav
# ph3-11-1.m4a.16kHz.mono.wav
# ph15-10-1.m4a.16kHz.mono.wav
# ph14-1-3.m4a.16kHz.mono.wav
# ph1-2-1.m4a.16kHz.mono.wav
# ph3-17-3.m4a.16kHz.mono.wav
# ph10-12-1.m4a.16kHz.mono.wav
# ph3-16-2.m4a.16kHz.mono.wav
# ph1-14-1.m4a.16kHz.mono.wav
# ph6-5-2.m4a.16kHz.mono.wav
# ph12-17-2.m4a.16kHz.mono.wav
# ph16-12-2.m4a.16kHz.mono.wav
# ph11-8-3.m4a.16kHz.mono.wav
# ph6-12-1.m4a.16kHz.mono.wav
# ph4-10-1.m4a.16kHz.mono.wav
# ph17-5-2.m4a.16kHz.mono.wav
# ph17-10-2.m4a.16kHz.mono.wav
# ph3-15-1.m4a.16kHz.mono.wav
# ph1-10-1.m4a.16kHz.mono.wav
# ph13-3-2.m4a.16kHz.mono.wav
# ph11-2-3.m4a.16kHz.mono.wav
# ph11-16-2.m4a.16kHz.mono.wav
# ph17-14-3.m4a.16kHz.mono.wav
# ph17-17-1.m4a.16kHz.mono.wav
# ph10-2-1.m4a.16kHz.mono.wav
# ph14-3-2.m4a.16kHz.mono.wav
# ph10-10-3.m4a.16kHz.mono.wav
# ph4-15-3.m4a.16kHz.mono.wav
# ph1-17-3.m4a.16kHz.mono.wav
# ph12-5-2.m4a.16kHz.mono.wav
# ph13-12-3.m4a.16kHz.mono.wav
# ph10-11-3.m4a.16kHz.mono.wav
# ph6-4-1.m4a.16kHz.mono.wav
# ph17-16-2.m4a.16kHz.mono.wav
# ph12-4-2.m4a.16kHz.mono.wav
# ph1-6-1.m4a.16kHz.mono.wav
# ph4-6-3.m4a.16kHz.mono.wav
# ph12-10-1.m4a.16kHz.mono.wav
# ph12-8-1.m4a.16kHz.mono.wav
# ph15-4-1.m4a.16kHz.mono.wav
# ph12-15-1.m4a.16kHz.mono.wav
# ph12-12-2.m4a.16kHz.mono.wav
# ph2-3-1.m4a.16kHz.mono.wav
# ph11-7-3.m4a.16kHz.mono.wav
# ph4-2-2.m4a.16kHz.mono.wav
# ph8-3-3.m4a.16kHz.mono.wav
# ph4-16-1.m4a.16kHz.mono.wav
# ph9-10-1.m4a.16kHz.mono.wav
# ph15-3-3.m4a.16kHz.mono.wav
# ph17-15-1.m4a.16kHz.mono.wav
# ph11-1-3.m4a.16kHz.mono.wav
# ph17-6-2.m4a.16kHz.mono.wav
# ph1-4-3.m4a.16kHz.mono.wav
# ph13-5-1.m4a.16kHz.mono.wav
# ph14-15-2.m4a.16kHz.mono.wav
# ph17-8-2.m4a.16kHz.mono.wav
# ph14-14-1.m4a.16kHz.mono.wav
# ph1-3-3.m4a.16kHz.mono.wav
# ph14-3-1.m4a.16kHz.mono.wav
# ph11-9-3.m4a.16kHz.mono.wav
# ph15-11-3.m4a.16kHz.mono.wav
# ph3-4-2.m4a.16kHz.mono.wav
# ph9-11-3.m4a.16kHz.mono.wav
# ph5-5-1.m4a.16kHz.mono.wav
# ph7-9-2.m4a.16kHz.mono.wav
# ph10-7-3.m4a.16kHz.mono.wav
# ph3-7-1.m4a.16kHz.mono.wav
# ph12-8-2.m4a.16kHz.mono.wav
# ph8-15-1.m4a.16kHz.mono.wav
# ph10-5-1.m4a.16kHz.mono.wav
# ph14-13-1.m4a.16kHz.mono.wav
# ph5-11-2.m4a.16kHz.mono.wav
# ph12-7-3.m4a.16kHz.mono.wav
# ph2-12-3.m4a.16kHz.mono.wav
# ph2-2-1.m4a.16kHz.mono.wav
# ph8-1-1.m4a.16kHz.mono.wav
# ph1-15-1.m4a.16kHz.mono.wav
# ph7-17-1.m4a.16kHz.mono.wav
# ph10-13-2.m4a.16kHz.mono.wav
# ph4-5-2.m4a.16kHz.mono.wav
# ph9-11-2.m4a.16kHz.mono.wav
# ph16-10-2.m4a.16kHz.mono.wav
# ph7-8-3.m4a.16kHz.mono.wav
# ph2-6-1.m4a.16kHz.mono.wav
# ph3-4-3.m4a.16kHz.mono.wav
# ph3-13-1.m4a.16kHz.mono.wav
# ph14-2-1.m4a.16kHz.mono.wav
# ph9-12-3.m4a.16kHz.mono.wav
# ph17-4-1.m4a.16kHz.mono.wav
# ph2-15-1.m4a.16kHz.mono.wav
# ph7-6-3.m4a.16kHz.mono.wav
# ph3-10-2.m4a.16kHz.mono.wav
# ph9-15-2.m4a.16kHz.mono.wav
# ph3-1-3.m4a.16kHz.mono.wav
# ph13-5-2.m4a.16kHz.mono.wav
# ph4-2-1.m4a.16kHz.mono.wav
# ph9-8-1.m4a.16kHz.mono.wav
# ph2-17-1.m4a.16kHz.mono.wav
# ph5-4-2.m4a.16kHz.mono.wav
# ph7-6-1.m4a.16kHz.mono.wav
# ph10-8-1.m4a.16kHz.mono.wav
# ph8-13-2.m4a.16kHz.mono.wav
# ph9-13-1.m4a.16kHz.mono.wav
# ph15-6-2.m4a.16kHz.mono.wav
# ph3-4-1.m4a.16kHz.mono.wav
# ph3-16-1.m4a.16kHz.mono.wav
# ph2-5-1.m4a.16kHz.mono.wav
# ph17-6-3.m4a.16kHz.mono.wav
# ph8-12-3.m4a.16kHz.mono.wav
# ph6-11-1.m4a.16kHz.mono.wav
# ph12-2-1.m4a.16kHz.mono.wav
# ph17-4-2.m4a.16kHz.mono.wav
# ph9-13-3.m4a.16kHz.mono.wav
# ph8-5-1.m4a.16kHz.mono.wav
# ph7-5-2.m4a.16kHz.mono.wav
# ph2-7-3.m4a.16kHz.mono.wav
# ph6-9-1.m4a.16kHz.mono.wav
# ph2-2-3.m4a.16kHz.mono.wav
# ph6-17-2.m4a.16kHz.mono.wav
# ph2-5-3.m4a.16kHz.mono.wav
# ph5-14-1.m4a.16kHz.mono.wav
# ph13-16-3.m4a.16kHz.mono.wav
# ph1-2-2.m4a.16kHz.mono.wav
# ph17-13-2.m4a.16kHz.mono.wav
# ph17-2-3.m4a.16kHz.mono.wav
# ph11-8-1.m4a.16kHz.mono.wav
# ph4-3-1.m4a.16kHz.mono.wav
# ph3-1-1.m4a.16kHz.mono.wav
# ph11-16-1.m4a.16kHz.mono.wav
# ph5-3-1.m4a.16kHz.mono.wav
# ph2-11-2.m4a.16kHz.mono.wav
# ph16-16-1.m4a.16kHz.mono.wav
# ph11-11-3.m4a.16kHz.mono.wav
# ph16-1-1.m4a.16kHz.mono.wav
# ph10-8-3.m4a.16kHz.mono.wav
# ph2-8-3.m4a.16kHz.mono.wav
# ph5-13-2.m4a.16kHz.mono.wav
# ph11-2-2.m4a.16kHz.mono.wav
# ph8-11-1.m4a.16kHz.mono.wav
# ph10-6-2.m4a.16kHz.mono.wav
# ph9-12-1.m4a.16kHz.mono.wav
# ph9-17-3.m4a.16kHz.mono.wav
# ph3-10-1.m4a.16kHz.mono.wav
# ph5-6-2.m4a.16kHz.mono.wav
# ph15-15-2.m4a.16kHz.mono.wav
# ph4-7-3.m4a.16kHz.mono.wav
# ph15-14-2.m4a.16kHz.mono.wav
# ph9-4-1.m4a.16kHz.mono.wav
# ph15-13-3.m4a.16kHz.mono.wav
# ph13-11-2.m4a.16kHz.mono.wav
# ph12-13-1.m4a.16kHz.mono.wav
# ph15-11-2.m4a.16kHz.mono.wav
# ph11-5-1.m4a.16kHz.mono.wav
# ph12-17-3.m4a.16kHz.mono.wav
# ph14-3-3.m4a.16kHz.mono.wav
# ph11-6-2.m4a.16kHz.mono.wav
# ph11-17-1.m4a.16kHz.mono.wav
# ph8-10-3.m4a.16kHz.mono.wav
# ph5-2-1.m4a.16kHz.mono.wav
# ph16-14-1.m4a.16kHz.mono.wav
# ph11-17-3.m4a.16kHz.mono.wav
# ph16-17-1.m4a.16kHz.mono.wav
# ph14-12-3.m4a.16kHz.mono.wav
# ph13-4-1.m4a.16kHz.mono.wav
# ph5-16-1.m4a.16kHz.mono.wav
# ph8-11-2.m4a.16kHz.mono.wav
# ph7-16-2.m4a.16kHz.mono.wav
# ph4-10-3.m4a.16kHz.mono.wav
# ph9-12-2.m4a.16kHz.mono.wav
# ph3-14-3.m4a.16kHz.mono.wav
# ph10-1-3.m4a.16kHz.mono.wav
# ph8-17-3.m4a.16kHz.mono.wav
# ph9-17-1.m4a.16kHz.mono.wav
# ph2-10-3.m4a.16kHz.mono.wav
# ph6-4-3.m4a.16kHz.mono.wav
# ph15-15-3.m4a.16kHz.mono.wav
# ph16-13-3.m4a.16kHz.mono.wav
# ph4-8-2.m4a.16kHz.mono.wav
# ph1-8-2.m4a.16kHz.mono.wav
# ph6-12-3.m4a.16kHz.mono.wav
# ph8-9-2.m4a.16kHz.mono.wav
# ph10-15-1.m4a.16kHz.mono.wav
# ph6-12-2.m4a.16kHz.mono.wav
# ph17-10-3.m4a.16kHz.mono.wav
# ph13-1-3.m4a.16kHz.mono.wav
# ph12-12-1.m4a.16kHz.mono.wav
# ph3-11-2.m4a.16kHz.mono.wav
# ph17-11-1.m4a.16kHz.mono.wav
# ph5-16-3.m4a.16kHz.mono.wav
# ph8-12-2.m4a.16kHz.mono.wav
# ph7-13-1.m4a.16kHz.mono.wav
# ph5-10-1.m4a.16kHz.mono.wav
# ph10-9-1.m4a.16kHz.mono.wav
# ph14-6-1.m4a.16kHz.mono.wav
# ph10-4-3.m4a.16kHz.mono.wav
# ph16-14-3.m4a.16kHz.mono.wav
# ph12-5-3.m4a.16kHz.mono.wav
# ph10-11-1.m4a.16kHz.mono.wav
# ph1-17-2.m4a.16kHz.mono.wav
# ph1-9-1.m4a.16kHz.mono.wav
# ph14-11-3.m4a.16kHz.mono.wav
# ph7-14-2.m4a.16kHz.mono.wav
# ph8-9-1.m4a.16kHz.mono.wav
# ph6-7-2.m4a.16kHz.mono.wav
# ph11-11-1.m4a.16kHz.mono.wav
# ph6-3-1.m4a.16kHz.mono.wav
# ph6-9-2.m4a.16kHz.mono.wav
# ph13-12-1.m4a.16kHz.mono.wav
# ph4-17-2.m4a.16kHz.mono.wav
# ph7-15-2.m4a.16kHz.mono.wav
# ph8-1-2.m4a.16kHz.mono.wav
# ph3-10-3.m4a.16kHz.mono.wav
# ph2-16-2.m4a.16kHz.mono.wav
# ph3-13-3.m4a.16kHz.mono.wav
# ph14-9-1.m4a.16kHz.mono.wav
# ph8-8-3.m4a.16kHz.mono.wav
# ph5-15-3.m4a.16kHz.mono.wav
# ph17-5-1.m4a.16kHz.mono.wav
# ph16-3-3.m4a.16kHz.mono.wav
# ph4-4-3.m4a.16kHz.mono.wav
# ph8-16-3.m4a.16kHz.mono.wav
# ph12-7-2.m4a.16kHz.mono.wav
# ph8-6-2.m4a.16kHz.mono.wav
# ph17-12-3.m4a.16kHz.mono.wav
# ph17-6-1.m4a.16kHz.mono.wav
# ph13-16-1.m4a.16kHz.mono.wav
# ph5-1-3.m4a.16kHz.mono.wav
# ph8-13-1.m4a.16kHz.mono.wav
# ph7-3-2.m4a.16kHz.mono.wav
# ph3-8-1.m4a.16kHz.mono.wav
# ph12-11-2.m4a.16kHz.mono.wav
# ph14-5-1.m4a.16kHz.mono.wav
# ph5-8-3.m4a.16kHz.mono.wav
# ph13-15-2.m4a.16kHz.mono.wav
# ph1-13-3.m4a.16kHz.mono.wav
# ph5-7-1.m4a.16kHz.mono.wav
# ph6-9-3.m4a.16kHz.mono.wav
# ph2-7-2.m4a.16kHz.mono.wav
# ph1-11-3.m4a.16kHz.mono.wav
# ph5-9-1.m4a.16kHz.mono.wav
# ph15-5-1.m4a.16kHz.mono.wav
# ph15-10-3.m4a.16kHz.mono.wav
# ph12-17-1.m4a.16kHz.mono.wav
# ph8-5-3.m4a.16kHz.mono.wav
# ph10-12-2.m4a.16kHz.mono.wav
# ph15-3-1.m4a.16kHz.mono.wav
# ph3-5-1.m4a.16kHz.mono.wav
# ph15-7-2.m4a.16kHz.mono.wav
# ph2-13-1.m4a.16kHz.mono.wav
# ph16-6-3.m4a.16kHz.mono.wav
# ph17-17-2.m4a.16kHz.mono.wav
# ph4-2-3.m4a.16kHz.mono.wav
# ph14-17-2.m4a.16kHz.mono.wav
# ph9-9-3.m4a.16kHz.mono.wav
# ph17-15-3.m4a.16kHz.mono.wav
# ph14-10-1.m4a.16kHz.mono.wav
# ph9-5-1.m4a.16kHz.mono.wav
# ph1-8-1.m4a.16kHz.mono.wav
# ph6-5-1.m4a.16kHz.mono.wav
# ph1-6-2.m4a.16kHz.mono.wav
# ph5-4-3.m4a.16kHz.mono.wav
# ph13-13-3.m4a.16kHz.mono.wav
# ph3-9-1.m4a.16kHz.mono.wav
# ph8-17-1.m4a.16kHz.mono.wav
# ph7-14-3.m4a.16kHz.mono.wav
# ph7-1-2.m4a.16kHz.mono.wav
# ph16-15-3.m4a.16kHz.mono.wav
# ph6-17-1.m4a.16kHz.mono.wav
# ph2-17-2.m4a.16kHz.mono.wav
# ph1-3-2.m4a.16kHz.mono.wav
# ph1-10-3.m4a.16kHz.mono.wav
# ph13-7-3.m4a.16kHz.mono.wav
# ph17-1-3.m4a.16kHz.mono.wav
# ph9-3-2.m4a.16kHz.mono.wav
# ph4-15-2.m4a.16kHz.mono.wav
# ph1-4-1.m4a.16kHz.mono.wav
# ph6-3-2.m4a.16kHz.mono.wav
# ph17-9-1.m4a.16kHz.mono.wav
# ph8-4-3.m4a.16kHz.mono.wav
# ph8-6-1.m4a.16kHz.mono.wav
# ph17-16-1.m4a.16kHz.mono.wav
# ph5-8-2.m4a.16kHz.mono.wav
# ph17-17-3.m4a.16kHz.mono.wav
# ph8-2-2.m4a.16kHz.mono.wav
# ph11-9-2.m4a.16kHz.mono.wav
# ph11-12-3.m4a.16kHz.mono.wav
# ph14-2-3.m4a.16kHz.mono.wav
# ph17-2-2.m4a.16kHz.mono.wav
# ph8-3-1.m4a.16kHz.mono.wav
# ph14-7-2.m4a.16kHz.mono.wav
# ph6-2-1.m4a.16kHz.mono.wav
# ph1-14-3.m4a.16kHz.mono.wav
# ph5-2-3.m4a.16kHz.mono.wav
# ph15-1-3.m4a.16kHz.mono.wav
# ph8-14-1.m4a.16kHz.mono.wav
# ph4-12-3.m4a.16kHz.mono.wav
# ph9-10-3.m4a.16kHz.mono.wav
# ph6-10-2.m4a.16kHz.mono.wav
# ph4-8-1.m4a.16kHz.mono.wav
# ph2-16-3.m4a.16kHz.mono.wav
# ph1-6-3.m4a.16kHz.mono.wav
# ph7-4-2.m4a.16kHz.mono.wav
# ph15-1-1.m4a.16kHz.mono.wav
# ph7-2-2.m4a.16kHz.mono.wav
# ph9-13-2.m4a.16kHz.mono.wav
# ph10-10-2.m4a.16kHz.mono.wav
# ph16-15-1.m4a.16kHz.mono.wav
# ph13-9-1.m4a.16kHz.mono.wav
# ph8-15-2.m4a.16kHz.mono.wav
# ph16-12-3.m4a.16kHz.mono.wav
# ph10-8-2.m4a.16kHz.mono.wav
# ph7-16-1.m4a.16kHz.mono.wav
# ph5-5-2.m4a.16kHz.mono.wav
# ph10-12-3.m4a.16kHz.mono.wav
# ph5-12-1.m4a.16kHz.mono.wav
# ph1-7-2.m4a.16kHz.mono.wav
# ph12-7-1.m4a.16kHz.mono.wav
# ph8-7-1.m4a.16kHz.mono.wav
# ph14-16-1.m4a.16kHz.mono.wav
# ph16-4-2.m4a.16kHz.mono.wav
# ph15-12-3.m4a.16kHz.mono.wav
# ph4-5-3.m4a.16kHz.mono.wav
# ph4-10-2.m4a.16kHz.mono.wav
# ph3-12-2.m4a.16kHz.mono.wav
# ph3-14-1.m4a.16kHz.mono.wav
# ph12-5-1.m4a.16kHz.mono.wav
# ph11-13-3.m4a.16kHz.mono.wav
# ph15-16-1.m4a.16kHz.mono.wav
# ph8-4-2.m4a.16kHz.mono.wav
# ph10-10-1.m4a.16kHz.mono.wav
# ph11-14-1.m4a.16kHz.mono.wav
# ph7-8-1.m4a.16kHz.mono.wav
# ph9-7-2.m4a.16kHz.mono.wav
# ph5-3-2.m4a.16kHz.mono.wav
# ph4-14-3.m4a.16kHz.mono.wav
# ph9-2-3.m4a.16kHz.mono.wav
# ph5-13-3.m4a.16kHz.mono.wav
# ph16-9-1.m4a.16kHz.mono.wav
# ph17-16-3.m4a.16kHz.mono.wav
# ph17-7-2.m4a.16kHz.mono.wav
# ph5-5-3.m4a.16kHz.mono.wav
# ph17-12-1.m4a.16kHz.mono.wav
# ph6-7-3.m4a.16kHz.mono.wav
# ph2-15-2.m4a.16kHz.mono.wav
# ph13-5-3.m4a.16kHz.mono.wav
# ph12-6-3.m4a.16kHz.mono.wav
# ph4-13-3.m4a.16kHz.mono.wav
# ph8-4-1.m4a.16kHz.mono.wav
# ph2-9-1.m4a.16kHz.mono.wav
# ph16-6-2.m4a.16kHz.mono.wav
# ph5-15-1.m4a.16kHz.mono.wav
# ph8-16-1.m4a.16kHz.mono.wav
# ph12-11-1.m4a.16kHz.mono.wav
# ph11-5-2.m4a.16kHz.mono.wav
# ph1-11-2.m4a.16kHz.mono.wav
# ph14-15-1.m4a.16kHz.mono.wav
# ph13-14-2.m4a.16kHz.mono.wav
# ph8-7-3.m4a.16kHz.mono.wav
# ph4-3-2.m4a.16kHz.mono.wav
# ph15-7-3.m4a.16kHz.mono.wav
# ph9-1-2.m4a.16kHz.mono.wav
# ph5-4-1.m4a.16kHz.mono.wav
# ph14-9-2.m4a.16kHz.mono.wav
# ph12-9-3.m4a.16kHz.mono.wav
# ph3-3-1.m4a.16kHz.mono.wav
# ph7-12-2.m4a.16kHz.mono.wav
# ph16-10-3.m4a.16kHz.mono.wav
# ph5-16-2.m4a.16kHz.mono.wav
# ph13-6-3.m4a.16kHz.mono.wav
# ph3-5-3.m4a.16kHz.mono.wav
# ph8-8-2.m4a.16kHz.mono.wav
# ph12-16-2.m4a.16kHz.mono.wav
# ph11-16-3.m4a.16kHz.mono.wav
# ph7-3-1.m4a.16kHz.mono.wav
# ph2-4-2.m4a.16kHz.mono.wav
# ph12-11-3.m4a.16kHz.mono.wav
# ph9-6-2.m4a.16kHz.mono.wav
# ph13-9-2.m4a.16kHz.mono.wav
# ph10-13-3.m4a.16kHz.mono.wav
# ph11-9-1.m4a.16kHz.mono.wav
# ph6-15-3.m4a.16kHz.mono.wav
# ph6-16-2.m4a.16kHz.mono.wav
# ph4-13-2.m4a.16kHz.mono.wav
# ph7-6-2.m4a.16kHz.mono.wav
# ph1-8-3.m4a.16kHz.mono.wav
# ph13-10-3.m4a.16kHz.mono.wav
# ph17-1-2.m4a.16kHz.mono.wav
# ph1-12-1.m4a.16kHz.mono.wav
# ph5-14-3.m4a.16kHz.mono.wav
# ph5-10-3.m4a.16kHz.mono.wav
# ph9-15-1.m4a.16kHz.mono.wav
# ph9-9-1.m4a.16kHz.mono.wav
# ph14-17-1.m4a.16kHz.mono.wav
# ph15-8-3.m4a.16kHz.mono.wav
# ph12-8-3.m4a.16kHz.mono.wav
# ph13-14-3.m4a.16kHz.mono.wav
# ph11-17-2.m4a.16kHz.mono.wav
# ph9-7-1.m4a.16kHz.mono.wav
# ph7-1-3.m4a.16kHz.mono.wav
# ph17-1-1.m4a.16kHz.mono.wav
# ph2-11-3.m4a.16kHz.mono.wav
# ph13-8-3.m4a.16kHz.mono.wav
# ph9-4-3.m4a.16kHz.mono.wav
# ph9-11-1.m4a.16kHz.mono.wav
# ph10-16-1.m4a.16kHz.mono.wav
# ph15-12-2.m4a.16kHz.mono.wav
# ph9-5-2.m4a.16kHz.mono.wav
# ph12-2-2.m4a.16kHz.mono.wav
# ph12-6-2.m4a.16kHz.mono.wav
# ph2-13-2.m4a.16kHz.mono.wav
# ph3-7-2.m4a.16kHz.mono.wav
# ph3-2-3.m4a.16kHz.mono.wav

# %%
list=[filename for filename in os.listdir(directory) if filename.endswith(".wav")]

# %%
len(list)
# Out:
# 867

# %%
for filename in os.listdir(directory):
    if filename.endswith(".wav"):
        print(filename)
        # !file {filename}
# Out:
# ph4-11-1.m4a.16kHz.mono.wav
# ph4-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-3-3.m4a.16kHz.mono.wav
# ph10-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-14-2.m4a.16kHz.mono.wav
# ph6-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-16-3.m4a.16kHz.mono.wav
# ph6-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-2-2.m4a.16kHz.mono.wav
# ph2-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-15-3.m4a.16kHz.mono.wav
# ph7-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-14-1.m4a.16kHz.mono.wav
# ph17-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-5-3.m4a.16kHz.mono.wav
# ph10-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-15-3.m4a.16kHz.mono.wav
# ph13-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-3-3.m4a.16kHz.mono.wav
# ph2-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-9-3.m4a.16kHz.mono.wav
# ph15-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-11-2.m4a.16kHz.mono.wav
# ph11-11-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-10-1.m4a.16kHz.mono.wav
# ph7-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-17-3.m4a.16kHz.mono.wav
# ph6-17-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-4-3.m4a.16kHz.mono.wav
# ph11-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-1-1.m4a.16kHz.mono.wav
# ph12-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-3-3.m4a.16kHz.mono.wav
# ph5-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-2-3.m4a.16kHz.mono.wav
# ph16-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-2-1.m4a.16kHz.mono.wav
# ph15-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-12-1.m4a.16kHz.mono.wav
# ph8-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-9-2.m4a.16kHz.mono.wav
# ph3-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-2-3.m4a.16kHz.mono.wav
# ph7-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-14-2.m4a.16kHz.mono.wav
# ph3-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-1-2.m4a.16kHz.mono.wav
# ph4-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-3-3.m4a.16kHz.mono.wav
# ph11-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-17-1.m4a.16kHz.mono.wav
# ph10-17-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-6-1.m4a.16kHz.mono.wav
# ph4-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-9-2.m4a.16kHz.mono.wav
# ph12-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-12-3.m4a.16kHz.mono.wav
# ph7-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-14-3.m4a.16kHz.mono.wav
# ph6-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-13-2.m4a.16kHz.mono.wav
# ph6-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-7-1.m4a.16kHz.mono.wav
# ph14-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-14-2.m4a.16kHz.mono.wav
# ph1-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-9-3.m4a.16kHz.mono.wav
# ph2-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-13-3.m4a.16kHz.mono.wav
# ph2-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-5-2.m4a.16kHz.mono.wav
# ph14-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-14-2.m4a.16kHz.mono.wav
# ph8-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-12-1.m4a.16kHz.mono.wav
# ph4-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-12-1.m4a.16kHz.mono.wav
# ph11-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-14-2.m4a.16kHz.mono.wav
# ph4-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-14-2.m4a.16kHz.mono.wav
# ph16-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-3-3.m4a.16kHz.mono.wav
# ph4-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-3-1.m4a.16kHz.mono.wav
# ph9-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-5-2.m4a.16kHz.mono.wav
# ph1-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-15-3.m4a.16kHz.mono.wav
# ph8-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-4-3.m4a.16kHz.mono.wav
# ph14-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-6-1.m4a.16kHz.mono.wav
# ph5-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-14-3.m4a.16kHz.mono.wav
# ph11-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-10-2.m4a.16kHz.mono.wav
# ph9-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-8-2.m4a.16kHz.mono.wav
# ph6-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-17-2.m4a.16kHz.mono.wav
# ph13-17-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-6-3.m4a.16kHz.mono.wav
# ph9-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-10-1.m4a.16kHz.mono.wav
# ph6-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-12-3.m4a.16kHz.mono.wav
# ph1-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-11-1.m4a.16kHz.mono.wav
# ph5-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-3-2.m4a.16kHz.mono.wav
# ph16-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-14-2.m4a.16kHz.mono.wav
# ph17-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-7-1.m4a.16kHz.mono.wav
# ph17-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-1-1.m4a.16kHz.mono.wav
# ph10-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-1-2.m4a.16kHz.mono.wav
# ph16-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-1-3.m4a.16kHz.mono.wav
# ph12-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-6-1.m4a.16kHz.mono.wav
# ph11-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-8-2.m4a.16kHz.mono.wav
# ph3-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-15-3.m4a.16kHz.mono.wav
# ph2-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-6-2.m4a.16kHz.mono.wav
# ph2-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-1-3.m4a.16kHz.mono.wav
# ph2-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-15-2.m4a.16kHz.mono.wav
# ph1-15-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-11-2.m4a.16kHz.mono.wav
# ph16-11-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-2-3.m4a.16kHz.mono.wav
# ph6-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-12-1.m4a.16kHz.mono.wav
# ph16-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-15-3.m4a.16kHz.mono.wav
# ph10-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-6-1.m4a.16kHz.mono.wav
# ph3-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-1-2.m4a.16kHz.mono.wav
# ph2-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-10-3.m4a.16kHz.mono.wav
# ph11-10-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-14-3.m4a.16kHz.mono.wav
# ph2-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-11-3.m4a.16kHz.mono.wav
# ph6-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-10-2.m4a.16kHz.mono.wav
# ph14-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-14-2.m4a.16kHz.mono.wav
# ph10-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-16-2.m4a.16kHz.mono.wav
# ph4-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-8-2.m4a.16kHz.mono.wav
# ph13-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-15-3.m4a.16kHz.mono.wav
# ph12-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-6-2.m4a.16kHz.mono.wav
# ph14-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-17-3.m4a.16kHz.mono.wav
# ph10-17-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-10-1.m4a.16kHz.mono.wav
# ph13-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-13-3.m4a.16kHz.mono.wav
# ph7-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-2-1.m4a.16kHz.mono.wav
# ph7-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-10-1.m4a.16kHz.mono.wav
# ph2-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-10-2.m4a.16kHz.mono.wav
# ph2-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-5-1.m4a.16kHz.mono.wav
# ph7-5-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-13-2.m4a.16kHz.mono.wav
# ph3-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-3-3.m4a.16kHz.mono.wav
# ph17-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-11-1.m4a.16kHz.mono.wav
# ph15-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-11-3.m4a.16kHz.mono.wav
# ph7-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-6-2.m4a.16kHz.mono.wav
# ph13-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-3-2.m4a.16kHz.mono.wav
# ph10-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-15-2.m4a.16kHz.mono.wav
# ph5-15-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-11-1.m4a.16kHz.mono.wav
# ph2-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-14-2.m4a.16kHz.mono.wav
# ph12-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-1-1.m4a.16kHz.mono.wav
# ph9-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-10-2.m4a.16kHz.mono.wav
# ph15-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-4-2.m4a.16kHz.mono.wav
# ph13-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-15-1.m4a.16kHz.mono.wav
# ph4-15-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-15-2.m4a.16kHz.mono.wav
# ph16-15-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-1-2.m4a.16kHz.mono.wav
# ph13-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-13-1.m4a.16kHz.mono.wav
# ph17-13-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-10-2.m4a.16kHz.mono.wav
# ph11-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-16-1.m4a.16kHz.mono.wav
# ph12-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-7-3.m4a.16kHz.mono.wav
# ph17-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-1-1.m4a.16kHz.mono.wav
# ph14-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-7-3.m4a.16kHz.mono.wav
# ph9-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-17-2.m4a.16kHz.mono.wav
# ph5-17-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-9-3.m4a.16kHz.mono.wav
# ph5-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-6-3.m4a.16kHz.mono.wav
# ph6-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-6-1.m4a.16kHz.mono.wav
# ph15-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-13-2.m4a.16kHz.mono.wav
# ph16-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-1-1.m4a.16kHz.mono.wav
# ph2-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-3-3.m4a.16kHz.mono.wav
# ph3-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-3-3.m4a.16kHz.mono.wav
# ph7-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-14-3.m4a.16kHz.mono.wav
# ph9-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-7-2.m4a.16kHz.mono.wav
# ph7-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-12-2.m4a.16kHz.mono.wav
# ph13-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-1-1.m4a.16kHz.mono.wav
# ph6-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-10-3.m4a.16kHz.mono.wav
# ph7-10-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-7-3.m4a.16kHz.mono.wav
# ph1-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-17-3.m4a.16kHz.mono.wav
# ph13-17-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-10-1.m4a.16kHz.mono.wav
# ph11-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-6-1.m4a.16kHz.mono.wav
# ph6-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-8-3.m4a.16kHz.mono.wav
# ph3-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-11-1.m4a.16kHz.mono.wav
# ph1-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-7-2.m4a.16kHz.mono.wav
# ph4-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-15-3.m4a.16kHz.mono.wav
# ph9-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-6-3.m4a.16kHz.mono.wav
# ph3-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-9-1.m4a.16kHz.mono.wav
# ph15-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-6-3.m4a.16kHz.mono.wav
# ph15-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-17-1.m4a.16kHz.mono.wav
# ph4-17-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-14-3.m4a.16kHz.mono.wav
# ph15-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-6-2.m4a.16kHz.mono.wav
# ph3-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-3-1.m4a.16kHz.mono.wav
# ph1-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-14-2.m4a.16kHz.mono.wav
# ph14-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-10-2.m4a.16kHz.mono.wav
# ph5-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-16-3.m4a.16kHz.mono.wav
# ph4-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-9-3.m4a.16kHz.mono.wav
# ph10-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-13-3.m4a.16kHz.mono.wav
# ph17-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-1-3.m4a.16kHz.mono.wav
# ph16-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-13-2.m4a.16kHz.mono.wav
# ph12-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-13-1.m4a.16kHz.mono.wav
# ph1-13-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-10-3.m4a.16kHz.mono.wav
# ph12-10-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-11-3.m4a.16kHz.mono.wav
# ph4-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-1-1.m4a.16kHz.mono.wav
# ph4-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-12-3.m4a.16kHz.mono.wav
# ph5-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-12-2.m4a.16kHz.mono.wav
# ph1-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-4-1.m4a.16kHz.mono.wav
# ph14-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-6-3.m4a.16kHz.mono.wav
# ph2-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-14-3.m4a.16kHz.mono.wav
# ph8-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-13-3.m4a.16kHz.mono.wav
# ph12-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-7-1.m4a.16kHz.mono.wav
# ph2-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-7-1.m4a.16kHz.mono.wav
# ph4-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-7-2.m4a.16kHz.mono.wav
# ph8-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-8-1.m4a.16kHz.mono.wav
# ph13-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-8-1.m4a.16kHz.mono.wav
# ph2-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-1-2.m4a.16kHz.mono.wav
# ph12-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-14-2.m4a.16kHz.mono.wav
# ph11-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-3-3.m4a.16kHz.mono.wav
# ph9-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-3-1.m4a.16kHz.mono.wav
# ph10-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-1-2.m4a.16kHz.mono.wav
# ph15-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-6-1.m4a.16kHz.mono.wav
# ph9-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-3-2.m4a.16kHz.mono.wav
# ph11-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-10-1.m4a.16kHz.mono.wav
# ph17-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-15-1.m4a.16kHz.mono.wav
# ph15-15-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-12-2.m4a.16kHz.mono.wav
# ph4-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-5-2.m4a.16kHz.mono.wav
# ph16-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-14-1.m4a.16kHz.mono.wav
# ph4-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-12-2.m4a.16kHz.mono.wav
# ph17-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-7-3.m4a.16kHz.mono.wav
# ph16-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-3-2.m4a.16kHz.mono.wav
# ph12-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-17-2.m4a.16kHz.mono.wav
# ph10-17-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-12-1.m4a.16kHz.mono.wav
# ph15-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-9-1.m4a.16kHz.mono.wav
# ph12-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-9-1.m4a.16kHz.mono.wav
# ph7-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-3-2.m4a.16kHz.mono.wav
# ph2-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-14-2.m4a.16kHz.mono.wav
# ph9-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-15-1.m4a.16kHz.mono.wav
# ph11-15-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-9-2.m4a.16kHz.mono.wav
# ph17-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-2-3.m4a.16kHz.mono.wav
# ph10-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-17-1.m4a.16kHz.mono.wav
# ph3-17-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-7-1.m4a.16kHz.mono.wav
# ph7-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-12-2.m4a.16kHz.mono.wav
# ph5-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-6-3.m4a.16kHz.mono.wav
# ph10-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-4-2.m4a.16kHz.mono.wav
# ph9-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-1-2.m4a.16kHz.mono.wav
# ph11-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-8-3.m4a.16kHz.mono.wav
# ph17-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-7-3.m4a.16kHz.mono.wav
# ph5-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-15-2.m4a.16kHz.mono.wav
# ph10-15-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-1-2.m4a.16kHz.mono.wav
# ph3-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-7-1.m4a.16kHz.mono.wav
# ph13-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-13-1.m4a.16kHz.mono.wav
# ph16-13-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-7-2.m4a.16kHz.mono.wav
# ph11-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-5-3.m4a.16kHz.mono.wav
# ph11-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-11-1.m4a.16kHz.mono.wav
# ph16-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-17-2.m4a.16kHz.mono.wav
# ph9-17-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-4-1.m4a.16kHz.mono.wav
# ph2-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-13-3.m4a.16kHz.mono.wav
# ph6-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-4-2.m4a.16kHz.mono.wav
# ph4-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-3-1.m4a.16kHz.mono.wav
# ph12-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-6-2.m4a.16kHz.mono.wav
# ph6-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-17-3.m4a.16kHz.mono.wav
# ph5-17-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-2-2.m4a.16kHz.mono.wav
# ph5-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-11-3.m4a.16kHz.mono.wav
# ph8-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-7-2.m4a.16kHz.mono.wav
# ph5-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-4-3.m4a.16kHz.mono.wav
# ph13-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-14-1.m4a.16kHz.mono.wav
# ph7-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-13-2.m4a.16kHz.mono.wav
# ph15-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-5-3.m4a.16kHz.mono.wav
# ph1-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-3-3.m4a.16kHz.mono.wav
# ph12-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-12-2.m4a.16kHz.mono.wav
# ph2-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-4-2.m4a.16kHz.mono.wav
# ph15-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-16-2.m4a.16kHz.mono.wav
# ph10-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-9-3.m4a.16kHz.mono.wav
# ph3-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-4-1.m4a.16kHz.mono.wav
# ph7-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-14-1.m4a.16kHz.mono.wav
# ph13-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-9-3.m4a.16kHz.mono.wav
# ph7-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-2-2.m4a.16kHz.mono.wav
# ph10-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-8-1.m4a.16kHz.mono.wav
# ph6-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-13-2.m4a.16kHz.mono.wav
# ph14-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-1-2.m4a.16kHz.mono.wav
# ph6-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-1-1.m4a.16kHz.mono.wav
# ph13-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-11-2.m4a.16kHz.mono.wav
# ph4-11-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-7-1.m4a.16kHz.mono.wav
# ph1-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-14-2.m4a.16kHz.mono.wav
# ph5-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-8-2.m4a.16kHz.mono.wav
# ph9-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-6-1.m4a.16kHz.mono.wav
# ph12-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-6-2.m4a.16kHz.mono.wav
# ph4-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-5-2.m4a.16kHz.mono.wav
# ph3-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-17-1.m4a.16kHz.mono.wav
# ph5-17-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-1-3.m4a.16kHz.mono.wav
# ph9-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-9-2.m4a.16kHz.mono.wav
# ph5-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-16-3.m4a.16kHz.mono.wav
# ph14-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-2-1.m4a.16kHz.mono.wav
# ph17-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-8-3.m4a.16kHz.mono.wav
# ph4-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-9-2.m4a.16kHz.mono.wav
# ph10-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-11-3.m4a.16kHz.mono.wav
# ph17-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-17-1.m4a.16kHz.mono.wav
# ph1-17-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-10-2.m4a.16kHz.mono.wav
# ph13-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-8-1.m4a.16kHz.mono.wav
# ph15-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-14-1.m4a.16kHz.mono.wav
# ph15-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-16-2.m4a.16kHz.mono.wav
# ph14-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-16-1.m4a.16kHz.mono.wav
# ph9-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-3-1.m4a.16kHz.mono.wav
# ph13-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-6-3.m4a.16kHz.mono.wav
# ph11-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-10-2.m4a.16kHz.mono.wav
# ph8-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-16-3.m4a.16kHz.mono.wav
# ph16-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-6-1.m4a.16kHz.mono.wav
# ph13-6-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-8-2.m4a.16kHz.mono.wav
# ph11-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-10-1.m4a.16kHz.mono.wav
# ph16-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-8-3.m4a.16kHz.mono.wav
# ph16-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-2-1.m4a.16kHz.mono.wav
# ph9-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-16-3.m4a.16kHz.mono.wav
# ph12-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-14-3.m4a.16kHz.mono.wav
# ph12-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-9-3.m4a.16kHz.mono.wav
# ph16-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-1-1.m4a.16kHz.mono.wav
# ph11-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-2-3.m4a.16kHz.mono.wav
# ph13-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-8-2.m4a.16kHz.mono.wav
# ph15-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-8-1.m4a.16kHz.mono.wav
# ph14-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-2-1.m4a.16kHz.mono.wav
# ph13-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-7-3.m4a.16kHz.mono.wav
# ph14-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-5-2.m4a.16kHz.mono.wav
# ph15-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-9-2.m4a.16kHz.mono.wav
# ph4-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-13-2.m4a.16kHz.mono.wav
# ph13-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-1-1.m4a.16kHz.mono.wav
# ph1-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-3-3.m4a.16kHz.mono.wav
# ph13-3-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-2-2.m4a.16kHz.mono.wav
# ph13-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-4-1.m4a.16kHz.mono.wav
# ph11-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-1-2.m4a.16kHz.mono.wav
# ph5-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-4-1.m4a.16kHz.mono.wav
# ph16-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-15-3.m4a.16kHz.mono.wav
# ph11-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-4-1.m4a.16kHz.mono.wav
# ph10-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-5-2.m4a.16kHz.mono.wav
# ph2-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-4-3.m4a.16kHz.mono.wav
# ph16-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-2-1.m4a.16kHz.mono.wav
# ph16-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-4-2.m4a.16kHz.mono.wav
# ph1-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-13-1.m4a.16kHz.mono.wav
# ph10-13-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-2-1.m4a.16kHz.mono.wav
# ph3-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-12-1.m4a.16kHz.mono.wav
# ph2-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-5-3.m4a.16kHz.mono.wav
# ph15-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-1-2.m4a.16kHz.mono.wav
# ph1-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-13-1.m4a.16kHz.mono.wav
# ph4-13-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-14-3.m4a.16kHz.mono.wav
# ph10-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-9-3.m4a.16kHz.mono.wav
# ph13-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-11-2.m4a.16kHz.mono.wav
# ph7-11-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-8-2.m4a.16kHz.mono.wav
# ph16-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-3-1.m4a.16kHz.mono.wav
# ph16-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-9-3.m4a.16kHz.mono.wav
# ph8-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-7-1.m4a.16kHz.mono.wav
# ph16-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-9-3.m4a.16kHz.mono.wav
# ph17-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-8-2.m4a.16kHz.mono.wav
# ph14-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-16-1.m4a.16kHz.mono.wav
# ph1-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-14-1.m4a.16kHz.mono.wav
# ph6-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-4-2.m4a.16kHz.mono.wav
# ph10-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-17-3.m4a.16kHz.mono.wav
# ph4-17-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-4-2.m4a.16kHz.mono.wav
# ph11-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-3-2.m4a.16kHz.mono.wav
# ph17-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-10-2.m4a.16kHz.mono.wav
# ph12-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-11-3.m4a.16kHz.mono.wav
# ph16-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-16-1.m4a.16kHz.mono.wav
# ph6-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-5-2.m4a.16kHz.mono.wav
# ph8-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-7-1.m4a.16kHz.mono.wav
# ph6-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-2-3.m4a.16kHz.mono.wav
# ph8-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-16-3.m4a.16kHz.mono.wav
# ph1-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-1-3.m4a.16kHz.mono.wav
# ph8-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-2-2.m4a.16kHz.mono.wav
# ph16-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-3-2.m4a.16kHz.mono.wav
# ph15-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-9-3.m4a.16kHz.mono.wav
# ph14-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-1-1.m4a.16kHz.mono.wav
# ph5-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-9-2.m4a.16kHz.mono.wav
# ph1-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-3-2.m4a.16kHz.mono.wav
# ph3-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-16-2.m4a.16kHz.mono.wav
# ph13-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-17-3.m4a.16kHz.mono.wav
# ph16-17-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-4-3.m4a.16kHz.mono.wav
# ph2-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-13-1.m4a.16kHz.mono.wav
# ph5-13-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-14-3.m4a.16kHz.mono.wav
# ph14-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-12-1.m4a.16kHz.mono.wav
# ph14-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-14-1.m4a.16kHz.mono.wav
# ph2-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-15-2.m4a.16kHz.mono.wav
# ph11-15-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-4-1.m4a.16kHz.mono.wav
# ph4-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-17-3.m4a.16kHz.mono.wav
# ph2-17-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-5-1.m4a.16kHz.mono.wav
# ph4-5-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-10-2.m4a.16kHz.mono.wav
# ph7-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-4-2.m4a.16kHz.mono.wav
# ph14-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-11-1.m4a.16kHz.mono.wav
# ph13-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-13-2.m4a.16kHz.mono.wav
# ph11-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-7-1.m4a.16kHz.mono.wav
# ph10-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-1-3.m4a.16kHz.mono.wav
# ph1-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-6-3.m4a.16kHz.mono.wav
# ph5-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-16-3.m4a.16kHz.mono.wav
# ph3-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-15-3.m4a.16kHz.mono.wav
# ph1-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-2-3.m4a.16kHz.mono.wav
# ph15-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-5-3.m4a.16kHz.mono.wav
# ph7-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-4-3.m4a.16kHz.mono.wav
# ph12-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-8-1.m4a.16kHz.mono.wav
# ph17-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-14-2.m4a.16kHz.mono.wav
# ph2-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-5-3.m4a.16kHz.mono.wav
# ph17-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-2-1.m4a.16kHz.mono.wav
# ph11-2-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-8-3.m4a.16kHz.mono.wav
# ph6-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-17-2.m4a.16kHz.mono.wav
# ph16-17-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-5-3.m4a.16kHz.mono.wav
# ph16-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-13-2.m4a.16kHz.mono.wav
# ph7-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-10-2.m4a.16kHz.mono.wav
# ph1-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-8-2.m4a.16kHz.mono.wav
# ph7-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-2-2.m4a.16kHz.mono.wav
# ph3-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-16-2.m4a.16kHz.mono.wav
# ph15-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-8-3.m4a.16kHz.mono.wav
# ph14-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-7-3.m4a.16kHz.mono.wav
# ph7-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-4-3.m4a.16kHz.mono.wav
# ph17-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-9-1.m4a.16kHz.mono.wav
# ph4-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-2-2.m4a.16kHz.mono.wav
# ph14-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-1-1.m4a.16kHz.mono.wav
# ph7-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-16-3.m4a.16kHz.mono.wav
# ph9-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-13-1.m4a.16kHz.mono.wav
# ph13-13-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-8-2.m4a.16kHz.mono.wav
# ph2-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-14-1.m4a.16kHz.mono.wav
# ph12-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-12-3.m4a.16kHz.mono.wav
# ph3-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-12-2.m4a.16kHz.mono.wav
# ...
# ph5-2-3.m4a.16kHz.mono.wav
# ph5-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-1-3.m4a.16kHz.mono.wav
# ph15-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-14-1.m4a.16kHz.mono.wav
# ph8-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-12-3.m4a.16kHz.mono.wav
# ph4-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-10-3.m4a.16kHz.mono.wav
# ph9-10-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-10-2.m4a.16kHz.mono.wav
# ph6-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-8-1.m4a.16kHz.mono.wav
# ph4-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-16-3.m4a.16kHz.mono.wav
# ph2-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-6-3.m4a.16kHz.mono.wav
# ph1-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-4-2.m4a.16kHz.mono.wav
# ph7-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-1-1.m4a.16kHz.mono.wav
# ph15-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-2-2.m4a.16kHz.mono.wav
# ph7-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-13-2.m4a.16kHz.mono.wav
# ph9-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-10-2.m4a.16kHz.mono.wav
# ph10-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-15-1.m4a.16kHz.mono.wav
# ph16-15-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-9-1.m4a.16kHz.mono.wav
# ph13-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-15-2.m4a.16kHz.mono.wav
# ph8-15-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-12-3.m4a.16kHz.mono.wav
# ph16-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-8-2.m4a.16kHz.mono.wav
# ph10-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-16-1.m4a.16kHz.mono.wav
# ph7-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-5-2.m4a.16kHz.mono.wav
# ph5-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-12-3.m4a.16kHz.mono.wav
# ph10-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-12-1.m4a.16kHz.mono.wav
# ph5-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-7-2.m4a.16kHz.mono.wav
# ph1-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-7-1.m4a.16kHz.mono.wav
# ph12-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-7-1.m4a.16kHz.mono.wav
# ph8-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-16-1.m4a.16kHz.mono.wav
# ph14-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-4-2.m4a.16kHz.mono.wav
# ph16-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-12-3.m4a.16kHz.mono.wav
# ph15-12-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-5-3.m4a.16kHz.mono.wav
# ph4-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-10-2.m4a.16kHz.mono.wav
# ph4-10-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-12-2.m4a.16kHz.mono.wav
# ph3-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-14-1.m4a.16kHz.mono.wav
# ph3-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-5-1.m4a.16kHz.mono.wav
# ph12-5-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-13-3.m4a.16kHz.mono.wav
# ph11-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-16-1.m4a.16kHz.mono.wav
# ph15-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-4-2.m4a.16kHz.mono.wav
# ph8-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-10-1.m4a.16kHz.mono.wav
# ph10-10-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-14-1.m4a.16kHz.mono.wav
# ph11-14-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-8-1.m4a.16kHz.mono.wav
# ph7-8-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-7-2.m4a.16kHz.mono.wav
# ph9-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-3-2.m4a.16kHz.mono.wav
# ph5-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-14-3.m4a.16kHz.mono.wav
# ph4-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-2-3.m4a.16kHz.mono.wav
# ph9-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-13-3.m4a.16kHz.mono.wav
# ph5-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-9-1.m4a.16kHz.mono.wav
# ph16-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-16-3.m4a.16kHz.mono.wav
# ph17-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-7-2.m4a.16kHz.mono.wav
# ph17-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-5-3.m4a.16kHz.mono.wav
# ph5-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-12-1.m4a.16kHz.mono.wav
# ph17-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-7-3.m4a.16kHz.mono.wav
# ph6-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-15-2.m4a.16kHz.mono.wav
# ph2-15-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-5-3.m4a.16kHz.mono.wav
# ph13-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-6-3.m4a.16kHz.mono.wav
# ph12-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-13-3.m4a.16kHz.mono.wav
# ph4-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-4-1.m4a.16kHz.mono.wav
# ph8-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-9-1.m4a.16kHz.mono.wav
# ph2-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-6-2.m4a.16kHz.mono.wav
# ph16-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-15-1.m4a.16kHz.mono.wav
# ph5-15-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-16-1.m4a.16kHz.mono.wav
# ph8-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-11-1.m4a.16kHz.mono.wav
# ph12-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-5-2.m4a.16kHz.mono.wav
# ph11-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-11-2.m4a.16kHz.mono.wav
# ph1-11-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-15-1.m4a.16kHz.mono.wav
# ph14-15-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-14-2.m4a.16kHz.mono.wav
# ph13-14-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-7-3.m4a.16kHz.mono.wav
# ph8-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-3-2.m4a.16kHz.mono.wav
# ph4-3-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-7-3.m4a.16kHz.mono.wav
# ph15-7-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-1-2.m4a.16kHz.mono.wav
# ph9-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-4-1.m4a.16kHz.mono.wav
# ph5-4-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-9-2.m4a.16kHz.mono.wav
# ph14-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-9-3.m4a.16kHz.mono.wav
# ph12-9-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-3-1.m4a.16kHz.mono.wav
# ph3-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-12-2.m4a.16kHz.mono.wav
# ph7-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph16-10-3.m4a.16kHz.mono.wav
# ph16-10-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-16-2.m4a.16kHz.mono.wav
# ph5-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-6-3.m4a.16kHz.mono.wav
# ph13-6-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-5-3.m4a.16kHz.mono.wav
# ph3-5-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph8-8-2.m4a.16kHz.mono.wav
# ph8-8-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-16-2.m4a.16kHz.mono.wav
# ph12-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-16-3.m4a.16kHz.mono.wav
# ph11-16-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-3-1.m4a.16kHz.mono.wav
# ph7-3-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-4-2.m4a.16kHz.mono.wav
# ph2-4-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-11-3.m4a.16kHz.mono.wav
# ph12-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-6-2.m4a.16kHz.mono.wav
# ph9-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-9-2.m4a.16kHz.mono.wav
# ph13-9-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-13-3.m4a.16kHz.mono.wav
# ph10-13-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-9-1.m4a.16kHz.mono.wav
# ph11-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-15-3.m4a.16kHz.mono.wav
# ph6-15-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph6-16-2.m4a.16kHz.mono.wav
# ph6-16-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph4-13-2.m4a.16kHz.mono.wav
# ph4-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-6-2.m4a.16kHz.mono.wav
# ph7-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-8-3.m4a.16kHz.mono.wav
# ph1-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-10-3.m4a.16kHz.mono.wav
# ph13-10-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-1-2.m4a.16kHz.mono.wav
# ph17-1-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph1-12-1.m4a.16kHz.mono.wav
# ph1-12-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-14-3.m4a.16kHz.mono.wav
# ph5-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph5-10-3.m4a.16kHz.mono.wav
# ph5-10-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-15-1.m4a.16kHz.mono.wav
# ph9-15-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-9-1.m4a.16kHz.mono.wav
# ph9-9-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph14-17-1.m4a.16kHz.mono.wav
# ph14-17-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-8-3.m4a.16kHz.mono.wav
# ph15-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-8-3.m4a.16kHz.mono.wav
# ph12-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-14-3.m4a.16kHz.mono.wav
# ph13-14-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph11-17-2.m4a.16kHz.mono.wav
# ph11-17-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-7-1.m4a.16kHz.mono.wav
# ph9-7-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph7-1-3.m4a.16kHz.mono.wav
# ph7-1-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph17-1-1.m4a.16kHz.mono.wav
# ph17-1-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-11-3.m4a.16kHz.mono.wav
# ph2-11-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph13-8-3.m4a.16kHz.mono.wav
# ph13-8-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-4-3.m4a.16kHz.mono.wav
# ph9-4-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-11-1.m4a.16kHz.mono.wav
# ph9-11-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph10-16-1.m4a.16kHz.mono.wav
# ph10-16-1.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph15-12-2.m4a.16kHz.mono.wav
# ph15-12-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph9-5-2.m4a.16kHz.mono.wav
# ph9-5-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-2-2.m4a.16kHz.mono.wav
# ph12-2-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph12-6-2.m4a.16kHz.mono.wav
# ph12-6-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph2-13-2.m4a.16kHz.mono.wav
# ph2-13-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-7-2.m4a.16kHz.mono.wav
# ph3-7-2.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
# ph3-2-3.m4a.16kHz.mono.wav
# ph3-2-3.m4a.16kHz.mono.wav: RIFF (little-endian) data, WAVE audio, Microsoft PCM, 16 bit, mono 16000 Hz
